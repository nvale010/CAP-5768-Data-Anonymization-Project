# %%
#data manipulation
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/natal/Documents/Intro to Data Science/Hospital_Inpatient_Discharges_2019.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
# <ipython-input-2-d277f28c7cf9>:1: DtypeWarning: Columns (10,29) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('C:/Users/natal/Documents/Intro to Data Science/Hospital_Inpatient_Discharges_2019.csv')
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5902001.0
# 1         Hudson Valley     Westchester                     5902001.0
# 2         Hudson Valley     Westchester                     5902001.0
# 3         Hudson Valley     Westchester                     5902001.0
# 4         Hudson Valley     Westchester                     5902001.0
#
#    Permanent Facility Id                 Facility Name    Age Group  \
# 0                 1045.0  White Plains Hospital Center     30 to 49
# 1                 1045.0  White Plains Hospital Center  70 or Older
# 2                 1045.0  White Plains Hospital Center     50 to 69
# ...

# %%
df['Patient Disposition'].unique().tolist()
# Out:
# ['Home or Self Care',
#  'Left Against Medical Advice',
#  'Psychiatric Hospital or Unit of Hosp',
#  'Home w/ Home Health Services',
#  'Skilled Nursing Home',
#  'Inpatient Rehabilitation Facility',
#  'Expired',
#  'Short-term Hospital',
#  'Another Type Not Listed',
#  'Hospice - Home',
#  'Hospice - Medical Facility',
#  'Medicare Cert Long Term Care Hospital',
#  'Facility w/ Custodial/Supportive Care',
#  "Cancer Center or Children's Hospital",
#  'Court/Law Enforcement',
#  'Critical Access Hospital',
#  'Hosp Basd Medicare Approved Swing Bed',
#  'Federal Health Care Facility',
#  'Admitted from Ambulatory Surgery',
#  'Medicaid Cert Nursing Facility']

# %%
clinton = df[df['Hospital County'] == 'Clinton']

# %%
clinton[clinton['Patient Disposition'] == 'Hospice - Medical Facility']
# Out:
#         Hospital Service Area Hospital County  Operating Certificate Number  \
# 2338147       Capital/Adirond         Clinton                      901001.0
#
#          Permanent Facility Id  \
# 2338147                  135.0
#
#                                              Facility Name    Age Group  \
# 2338147  The University of Vermont Health Network - Cha...  70 or Older
#
#         Zip Code - 3 digits Gender   Race          Ethnicity Length of Stay  \
# 2338147                 129      F  White  Not Span/Hispanic              2
#
#         Type of Admission         Patient Disposition  Discharge Year  \
# 2338147         Emergency  Hospice - Medical Facility            2019
#
#         CCSR Diagnosis Code CCSR Diagnosis Description CCSR Procedure Code  \
# 2338147              DIG004       ESOPHAGEAL DISORDERS                 NaN
#
#         CCSR Procedure Description  APR DRG Code         APR DRG Description  \
# ...

# %%
df.tail()
# Out:
#         Hospital Service Area Hospital County  Operating Certificate Number  \
# 2339457         New York City           Kings                     7001021.0
# 2339458         New York City          Queens                     7003010.0
# 2339459         New York City       Manhattan                     7002054.0
# 2339460         New York City           Kings                     7001021.0
# 2339461           Long Island          Nassau                     2950002.0
#
#          Permanent Facility Id  \
# 2339457                 1306.0
# 2339458                 1637.0
# 2339459                 1458.0
# 2339460                 1306.0
# 2339461                  528.0
#
#                                              Facility Name    Age Group  \
# 2339457  New York - Presbyterian Brooklyn Methodist Hos...      0 to 17
# 2339458                     New York - Presbyterian/Queens      0 to 17
# 2339459  New York-Presbyterian Hospital - New York Weil...     50 to 69
# ...

# %%
# Each DRG is made up of the principal diagnoses that are assigned to them. In contrast, most MDCs are made up 
# of body systems, such a neurology, respiratory, digestive, and circulatory
list_DRG = df['APR DRG Description'].unique().tolist()
print(list_DRG)
# Out:
# ['VIRAL ILLNESS', 'ACUTE KIDNEY INJURY', 'KIDNEY & URINARY TRACT PROCEDURES FOR NONMALIGNANCY', 'ASTHMA', 'OVERDOSE', 'OSTEOMYELITIS, SEPTIC ARTHRITIS & OTHER MUSCULOSKELETAL INFECTIONS', 'OTHER SMALL & LARGE BOWEL PROCEDURES', 'OTHER PNEUMONIA', 'CHEST PAIN', 'CELLULITIS & OTHER SKIN INFECTIONS', 'FEVER', 'INTESTINAL OBSTRUCTION', 'HIP JOINT REPLACEMENT', 'POST-OP, POST-TRAUMA, OTHER DEVICE INFECTIONS W O.R. PROCEDURE', 'CERVICAL SPINAL FUSION & OTHER BACK/NECK PROC EXC DISC EXCIS/DECOMP', 'KNEE JOINT REPLACEMENT', 'MAJOR DEPRESSIVE DISORDERS & OTHER/UNSPECIFIED PSYCHOSES', 'SCHIZOPHRENIA', 'ALCOHOL & DRUG DEPENDENCE W REHAB OR REHAB/DETOX THERAPY', 'COAGULATION & PLATELET DISORDERS', 'HYPERTENSION', 'EXTENSIVE OR PROCEDURES FOR OTHER COMPLICATIONS OF TREATMENT', 'MULTIPLE SIGNIFICANT TRAUMA W/O O.R. PROCEDURE', 'NON-HYPOVOLEMIC SODIUM DISORDERS', 'NON-BACTERIAL INFECTIONS OF NERVOUS SYSTEM EXC VIRAL MENINGITIS', 'UTERINE & ADNEXA PROCEDURES FOR OVARIAN & ADNEXAL MALIGNANCY', 'REHAB
# ...

# %%
# The diagnoses in each MDC correspond to a single organ system
# Each MDC was constructed to correspond to a major organ system (e.g., Respiratory System, Circulatory System, Digestive System) 
list_MDC = df['APR MDC Description'].unique().tolist()
print(list_MDC)
# Out:
# ['INFECTIOUS AND PARASITIC DISEASES (SYSTEMIC OR UNSPECIFIED SITES)', 'DISEASES AND DISORDERS OF THE KIDNEY AND URINARY TRACT', 'DISEASES AND DISORDERS OF THE RESPIRATORY SYSTEM', 'INJURIES, POISONINGS AND TOXIC EFFECTS OF DRUGS', 'DISEASES AND DISORDERS OF THE MUSCULOSKELETAL SYSTEM AND CONNECTIVE TISSUE', 'DISEASES AND DISORDERS OF THE DIGESTIVE SYSTEM', 'DISEASES AND DISORDERS OF THE CIRCULATORY SYSTEM', 'DISEASES AND DISORDERS OF THE SKIN, SUBCUTANEOUS TISSUE AND BREAST', 'MENTAL DISEASES AND DISORDERS', 'ALCOHOL/DRUG USE AND ALCOHOL/DRUG INDUCED ORGANIC MENTAL DISORDERS', 'DISEASES AND DISORDERS OF THE BLOOD AND BLOOD FORMING ORGANS AND IMMUNOLOGICAL DISORDERS', 'HUMAN IMMUNODEFICIENCY VIRUS INFECTIONS', 'ENDOCRINE, NUTRITIONAL AND METABOLIC DISEASES AND DISORDERS', 'DISEASES AND DISORDERS OF THE NERVOUS SYSTEM', 'DISEASES AND DISORDERS OF THE FEMALE REPRODUCTIVE SYSTEM', 'FACTORS INFLUENCING HEALTH STATUS AND OTHER CONTACTS WITH HEALTH SERVICES', 'DISEASES AND DISORDERS OF THE 
# ...

# %%
# 6 million NAN values
df.isna().sum().sum()
# Out:
# 6498455

# %%
# 2 million values per column
values_per_column= df.count()
values_per_column
# Out:
# Hospital Service Area                  2329957
# Hospital County                        2329957
# Operating Certificate Number           2329957
# Permanent Facility Id                  2330391
# Facility Name                          2339462
# Age Group                              2339462
# Zip Code - 3 digits                    2296532
# Gender                                 2339462
# Race                                   2339462
# Ethnicity                              2339462
# Length of Stay                         2339462
# Type of Admission                      2339462
# Patient Disposition                    2339462
# Discharge Year                         2339462
# CCSR Diagnosis Code                    2339401
# CCSR Diagnosis Description             2339401
# CCSR Procedure Code                    1609763
# CCSR Procedure Description             1609763
# APR DRG Code                           2339449
# APR DRG Description                    2339449
# ...

# %%
#gets sum of all na values per column
na_by_column=df.isna().sum()

# %%
na_by_column
# Out:
# Hospital Service Area                     9505
# Hospital County                           9505
# Operating Certificate Number              9505
# Permanent Facility Id                     9071
# Facility Name                                0
# Age Group                                    0
# Zip Code - 3 digits                      42930
# Gender                                       0
# Race                                         0
# Ethnicity                                    0
# Length of Stay                               0
# Type of Admission                            0
# Patient Disposition                          0
# Discharge Year                               0
# CCSR Diagnosis Code                         61
# CCSR Diagnosis Description                  61
# CCSR Procedure Code                     729699
# CCSR Procedure Description              729699
# APR DRG Code                                13
# APR DRG Description                         13
# ...

# %%
#sum of na values per column that has na values
na_by_column[na_by_column>0]
# Out:
# Hospital Service Area                     9505
# Hospital County                           9505
# Operating Certificate Number              9505
# Permanent Facility Id                     9071
# Zip Code - 3 digits                      42930
# CCSR Diagnosis Code                         61
# CCSR Diagnosis Description                  61
# CCSR Procedure Code                     729699
# CCSR Procedure Description              729699
# APR DRG Code                                13
# APR DRG Description                         13
# APR MDC Code                                13
# APR MDC Description                         13
# APR Severity of Illness Code                13
# APR Severity of Illness Description       1447
# APR Risk of Mortality                     1447
# Payment Typology 2                      968787
# Payment Typology 3                     1867656
# Birth Weight                           2119017
# dtype: int64

# %%
# columns with no na values
na_by_column[na_by_column==0]
# Out:
# Facility Name                       0
# Age Group                           0
# Gender                              0
# Race                                0
# Ethnicity                           0
# Length of Stay                      0
# Type of Admission                   0
# Patient Disposition                 0
# Discharge Year                      0
# APR Medical Surgical Description    0
# Payment Typology 1                  0
# Emergency Department Indicator      0
# Total Charges                       0
# Total Costs                         0
# dtype: int64

# %%
# checking to see which columns contain less than 2329957 entries
values_per_column[values_per_column < 2329957]
# Out:
# Zip Code - 3 digits           2296532
# CCSR Procedure Code           1609763
# CCSR Procedure Description    1609763
# Payment Typology 2            1370675
# Payment Typology 3             471806
# Birth Weight                   220445
# dtype: int64

# %%
# all columns
cols = df.columns

# %%
# looking at numeric columns
num_columns = df._get_numeric_data().columns

# %%
num_columns
# Out:
# Index(['Operating Certificate Number', 'Permanent Facility Id',
#        'Discharge Year', 'APR DRG Code', 'APR MDC Code',
#        'APR Severity of Illness Code', 'Emergency Department Indicator'],
#       dtype='object')

# %%
# all columns - numeric columns = categorical columns
cat = list(set(cols)-set(num_columns))

# %%
print(cat)
# Out:
# ['CCSR Procedure Code', 'Payment Typology 1', 'CCSR Procedure Description', 'Total Charges', 'Birth Weight', 'Age Group', 'Race', 'CCSR Diagnosis Code', 'Hospital County', 'Payment Typology 2', 'APR DRG Description', 'APR Medical Surgical Description', 'APR Severity of Illness Description', 'Length of Stay', 'Ethnicity', 'Facility Name', 'Gender', 'Hospital Service Area', 'APR MDC Description', 'Total Costs', 'APR Risk of Mortality', 'Type of Admission', 'Payment Typology 3', 'CCSR Diagnosis Description', 'Zip Code - 3 digits', 'Patient Disposition']

# %%
df_new = df[['Hospital Service Area', 'Hospital County','Facility Name', 'Zip Code - 3 digits','Gender','Age Group', 'Race', 'Ethnicity','Patient Disposition','CCSR Diagnosis Description',
'APR Severity of Illness Description', 'APR Risk of Mortality','Payment Typology 1','Total Charges', 'Total Costs']]
df_new.head()
# Out:
#   Hospital Service Area Hospital County                 Facility Name  \
# 0         Hudson Valley     Westchester  White Plains Hospital Center
# 1         Hudson Valley     Westchester  White Plains Hospital Center
# 2         Hudson Valley     Westchester  White Plains Hospital Center
# 3         Hudson Valley     Westchester  White Plains Hospital Center
# 4         Hudson Valley     Westchester  White Plains Hospital Center
#
#   Zip Code - 3 digits Gender    Age Group                    Race  \
# 0                 106      M     30 to 49              Other Race
# 1                 105      F  70 or Older  Black/African American
# 2                 105      F     50 to 69              Other Race
# 3                 106      F     50 to 69  Black/African American
# 4                 105      F  70 or Older              Other Race
#
#            Ethnicity                   Patient Disposition  \
# 0  Not Span/Hispanic                     Home or Self Care
# ...

# %%
df_new= df_new.dropna()

# %%
df_new.head()
# Out:
#   Hospital Service Area Hospital County                 Facility Name  \
# 0         Hudson Valley     Westchester  White Plains Hospital Center
# 1         Hudson Valley     Westchester  White Plains Hospital Center
# 2         Hudson Valley     Westchester  White Plains Hospital Center
# 3         Hudson Valley     Westchester  White Plains Hospital Center
# 4         Hudson Valley     Westchester  White Plains Hospital Center
#
#   Zip Code - 3 digits Gender    Age Group                    Race  \
# 0                 106      M     30 to 49              Other Race
# 1                 105      F  70 or Older  Black/African American
# 2                 105      F     50 to 69              Other Race
# 3                 106      F     50 to 69  Black/African American
# 4                 105      F  70 or Older              Other Race
#
#            Ethnicity                   Patient Disposition  \
# 0  Not Span/Hispanic                     Home or Self Care
# ...

# %%
df_new.shape
# Out:
# (2294641, 15)

# %%
list_diagnosis = df_new['CCSR Diagnosis Description'].unique().tolist()

# %%
print(list_diagnosis)
# Out:
# ['VIRAL INFECTION', 'ACUTE AND UNSPECIFIED RENAL FAILURE', 'OTHER SPECIFIED AND UNSPECIFIED DISEASES OF KIDNEY AND URETERS', 'ASTHMA', 'SUICIDAL IDEATION/ATTEMPT/INTENTIONAL SELF-HARM', 'DIABETES MELLITUS WITH COMPLICATION', 'INTESTINAL OBSTRUCTION AND ILEUS', 'PNEUMONIA (EXCEPT THAT CAUSED BY TUBERCULOSIS)', 'NONSPECIFIC CHEST PAIN', 'SKIN AND SUBCUTANEOUS TISSUE INFECTIONS', 'FEVER', 'OSTEOARTHRITIS', 'COMPLICATION OF OTHER SURGICAL OR MEDICAL CARE, INJURY, INITIAL ENCOUNTER', 'SPONDYLOPATHIES/SPONDYLOARTHROPATHY (INCLUDING INFECTIVE)', 'COMPLICATION OF INTERNAL ORTHOPEDIC DEVICE OR IMPLANT, INITIAL ENCOUNTER', 'SCHIZOPHRENIA SPECTRUM AND OTHER PSYCHOTIC DISORDERS', 'ALCOHOL-RELATED DISORDERS', 'COAGULATION AND HEMORRHAGIC DISORDERS', 'HYPERTENSION WITH COMPLICATIONS AND SECONDARY HYPERTENSION', 'EFFECT OF OTHER EXTERNAL CAUSES, INITIAL ENCOUNTER', 'TRAUMATIC BRAIN INJURY (TBI); CONCUSSION, INITIAL ENCOUNTER', 'FLUID AND ELECTROLYTE DISORDERS', 'MENINGITIS', 'FEMALE REPRODUCTIVE SY
# ...

# %%
pivotTable = df_new.pivot_table(columns = ['CCSR Diagnosis Description'], aggfunc='size')
pivotTable.head()
# Out:
# CCSR Diagnosis Description
# ABDOMINAL HERNIA                                                 10930
# ABDOMINAL PAIN AND OTHER DIGESTIVE/ABDOMEN SIGNS AND SYMPTOMS     5747
# ABNORMAL FINDINGS WITHOUT DIAGNOSIS                               3687
# ACQUIRED ABSENCE OF LIMB OR ORGAN                                   31
# ACQUIRED DEFORMITIES (EXCLUDING FOOT)                              680
# dtype: int64

# %%
Diagnosis_less_than_amount= pivotTable[pivotTable < 5]

# %%
print(Diagnosis_less_than_amount)
# Out:
# CCSR Diagnosis Description
# ANTENATAL SCREENING                                              2
# ATYPICAL FRACTURE, SUBSEQUENT ENCOUNTER                          3
# EFFECT OF FOREIGN BODY ENTERING OPENING, SUBSEQUENT ENCOUNTER    2
# EFFECT OF OTHER EXTERNAL CAUSES, SEQUELA                         3
# EFFECT OF OTHER EXTERNAL CAUSES, SUBSEQUENT ENCOUNTER            2
# ENDOCRINE SYSTEM CANCERS - PARATHYROID                           4
# INJURY TO BLOOD VESSELS, SUBSEQUENT ENCOUNTER                    4
# LIFESTYLE/LIFE MANAGEMENT FACTORS                                3
# MENTAL AND SUBSTANCE USE DISORDERS; SEQUELA                      2
# OPEN WOUNDS OF HEAD AND NECK, SUBSEQUENT ENCOUNTER               2
# OTHER SPECIFIED CHRONIC ARTHROPATHY                              3
# OTHER SPECIFIED ENCOUNTERS AND COUNSELING                        2
# PERSONAL/FAMILY HISTORY OF DISEASE                               1
# REFRACTIVE ERROR                                                 4
# ...

# %%
Diagnosis_less_than_amount.count()
# Out:
# 16

# %%
# Diagnosis Description is not a good indicator of outlier illnesses

# %%
df_new[df_new['CCSR Diagnosis Description'] == 'ENDOCRINE SYSTEM CANCERS - PARATHYROID']
# Out:
#         Hospital Service Area Hospital County  \
# 1135403         New York City       Manhattan
# 1253119         New York City           Kings
# 1846982            Western NY            Erie
# 2045033         Hudson Valley     Westchester
#
#                             Facility Name Zip Code - 3 digits Gender  \
# 1135403               Lenox Hill Hospital                 114      F
# 1253119  Kingsbrook Jewish Medical Center                 112      M
# 1846982     Roswell Park Cancer Institute                 141      M
# 2045033      White Plains Hospital Center                 105      M
#
#            Age Group                    Race          Ethnicity  \
# 1135403     50 to 69                   White  Not Span/Hispanic
# 1253119  70 or Older  Black/African American  Not Span/Hispanic
# 1846982     50 to 69  Black/African American  Not Span/Hispanic
# 2045033  70 or Older  Black/African American  Not Span/Hispanic
#
# ...

# %%
#import sys
#!{sys.executable} -m pip install association-metrics

# %%
df_new_new = df_new[['Age Group','APR Severity of Illness Description', 'APR Risk of Mortality']]
df_new_new.head()
# Out:
#      Age Group APR Severity of Illness Description APR Risk of Mortality
# 0     30 to 49                            Moderate                 Minor
# 1  70 or Older                            Moderate              Moderate
# 2     50 to 69                             Extreme               Extreme
# 3     50 to 69                            Moderate                 Minor
# 4  70 or Older                            Moderate              Moderate

# %%
import association_metrics as am

# %%
# Convert your str columns to Category columns
df_new_new = df_new_new.apply(
        lambda x: x.astype("category") if x.dtype == "O" else x)

# %%
cramersv = am.CramersV(df_new_new)

# %%
cramersv.fit()
# Out:
#                                      Age Group  \
# Age Group                             1.000000
# APR Severity of Illness Description   0.249287
# APR Risk of Mortality                 0.343097
#
#                                      APR Severity of Illness Description  \
# Age Group                                                       0.249287
# APR Severity of Illness Description                             1.000000
# APR Risk of Mortality                                           0.595864
#
#                                      APR Risk of Mortality
# Age Group                                         0.343097
# APR Severity of Illness Description               0.595864
# APR Risk of Mortality                             1.000000

# %%
CrosstabResult = pd.crosstab(index=df_new['APR Risk of Mortality'],columns=df_new['Age Group'])
print(CrosstabResult)
# Out:
# Age Group              0 to 17  18 to 29  30 to 49  50 to 69  70 or Older
# APR Risk of Mortality
# Extreme                   1990      3224     11532     49645       103320
# Major                     5722      6326     27319    120335       249988
# Minor                   287814    185048    334552    306925       109961
# Moderate                 19513     15374     59070    174463       222520

# %%
CrosstabResult2 = pd.crosstab(index=df_new['APR Severity of Illness Description'],columns=df_new['Age Group'])
print(CrosstabResult2)
# Out:
# Age Group                            0 to 17  18 to 29  30 to 49  50 to 69  \
# APR Severity of Illness Description
# Extreme                                 7579      5863     19954     75984
# Major                                  34068     22846     69493    188902
# Minor                                 192023     94508    163097    134952
# Moderate                               81369     86755    179929    251530
#
# Age Group                            70 or Older
# APR Severity of Illness Description
# Extreme                                   120715
# Major                                     253472
# Minor                                      79454
# Moderate                                  232148

# %%
df_categorical = df_new[['Hospital Service Area', 'Hospital County','Facility Name', 'Zip Code - 3 digits','Gender','Age Group', 'Race', 'Ethnicity','Patient Disposition','CCSR Diagnosis Description',
'APR Severity of Illness Description', 'APR Risk of Mortality','Payment Typology 1']]

# %%
df_categorical = df_categorical.apply(
        lambda x: x.astype("category") if x.dtype == "O" else x)

# %%
cramersv1 = am.CramersV(df_categorical)

# %%
results=cramersv1.fit()

# %%
from sklearn import preprocessing

# %%
label = preprocessing.LabelEncoder()
data_encoded = pd.DataFrame()

for i in df_categorical.columns:
    data_encoded[i] = label.fit_transform(df_categorical[i])

# %%
data_encoded.head()
# Out:
#    Hospital Service Area  Hospital County  Facility Name  Zip Code - 3 digits  \
# 0                      3               53            199                    5
# 1                      3               53            199                    4
# 2                      3               53            199                    4
# 3                      3               53            199                    5
# 4                      3               53            199                    4
#
#    Gender  Age Group  Race  Ethnicity  Patient Disposition  \
# 0       1          2     2          1                    8
# 1       0          4     0          1                    8
# 2       0          3     2          1                    8
# 3       0          3     0          1                   14
# 4       0          4     2          1                   17
#
#    CCSR Diagnosis Description  APR Severity of Illness Description  \
# 0                         471                                    3
# ...

# %%
from scipy.stats import chi2_contingency

# %%
# Cramer's V for label encoded data
def cramers_V(var1,var2) :
  crosstab =np.array(pd.crosstab(var1,var2, rownames=None, colnames=None)) # Cross table building
  stat = chi2_contingency(crosstab)[0] # Keeping of the test statistic of the Chi2 test
  obs = np.sum(crosstab) # Number of observations
  mini = min(crosstab.shape)-1 # Take the minimum value between the columns and the rows of the cross table
  return (stat/(obs*mini))

# %%
rows= []

for var1 in data_encoded:
  col = []
  for var2 in data_encoded :
    cramers =cramers_V(data_encoded[var1], data_encoded[var2]) # Cramer's V test
    col.append(round(cramers,2)) # Keeping of the rounded value of the Cramer's V  
  rows.append(col)
  
cramers_results = np.array(rows)
encoded = pd.DataFrame(cramers_results, columns = data_encoded.columns, index =data_encoded.columns)



encoded
# Out:
#                                      Hospital Service Area  Hospital County  \
# Hospital Service Area                                 1.00             1.00
# Hospital County                                       1.00             1.00
# Facility Name                                         1.00             1.00
# Zip Code - 3 digits                                   0.81             0.32
# Gender                                                0.00             0.00
# Age Group                                             0.00             0.01
# Race                                                  0.06             0.09
# Ethnicity                                             0.02             0.05
# Patient Disposition                                   0.00             0.01
# CCSR Diagnosis Description                            0.01             0.00
# APR Severity of Illness Description                   0.00             0.00
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# using pearson coefficient on label encoded data
corr = data_encoded.corr()
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(corr, annot=True, fmt='.2f')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(encoded, annot=True, fmt='.2f')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.heatmap(results, annot=True, fmt='.2f')
plt.show()

# %%
import plotly.express as px

# %%
fig = px.treemap(df_categorical,path=['Hospital Service Area','Hospital County', 'Race'], color='Race')
fig.update_layout(
    uniformtext=dict(minsize=10, mode='hide'),
    margin = dict(t=50, l=25, r=25, b=25))
fig.show()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.rcParams['figure.figsize'] = (20, 10)

# %%
df_places = gpd.read_file('C:/Users/natal/Documents/Intro to Data Science/NYcounties.geojson')

# %%
df_places.head()
# Out:
#           geoid               name  \
# 0  05000US36041    Hamilton County
# 1  05000US36017    Chenango County
# 2  05000US36051  Livingston County
# 3  05000US36097    Schuyler County
# 4  05000US36095   Schoharie County
#
#                                             geometry
# 0  MULTIPOLYGON (((-74.82011 43.81851, -74.85417 ...
# 1  MULTIPOLYGON (((-75.40346 42.50870, -75.40019 ...
# 2  MULTIPOLYGON (((-78.06088 42.53636, -78.05929 ...
# 3  MULTIPOLYGON (((-77.10487 42.38929, -77.10720 ...
# 4  MULTIPOLYGON (((-74.33880 42.78224, -74.28945 ...

# %%
df_places.rename(columns={'name': 'Hospital County'}, inplace= True)

# %%
df_places['Hospital County']=df_places['Hospital County'].apply(lambda x: x.replace(' County', ''))

# %%
df_places['Hospital County']=df_places['Hospital County'].apply(lambda x: x.replace('New York', 'Manhattan'))

# %%
df_places['Hospital County']=df_places['Hospital County'].apply(lambda x: x.replace('St. Lawrence', 'St Lawrence'))

# %%
list_places = df_places['Hospital County'].unique().tolist()
display(list_places)
# Out:
# ['Hamilton',
#  'Chenango',
#  'Livingston',
#  'Schuyler',
#  'Schoharie',
#  'Rensselaer',
#  'Oneida',
#  'Wayne',
#  'Suffolk',
#  'Tioga',
#  'Rockland',
#  'Wyoming',
#  'Oswego',
#  'Orleans',
#  'Steuben',
#  'Washington',
#  'St Lawrence',
#  'Warren',
#  'Westchester',
#  'Tompkins',
#  'Otsego',
#  'Chautauqua',
#  'Seneca',
#  'Cayuga',
#  'Queens',
#  'Essex',
#  'Ulster',
#  'Sullivan',
#  'Chemung',
#  'Manhattan',
#  'Monroe',
#  'Nassau',
#  'Onondaga',
#  'Columbia',
#  'Dutchess',
#  'Schenectady',
#  'Saratoga',
#  'Greene',
#  'Ontario',
#  'Delaware',
#  'Allegany',
#  'Albany',
#  'Bronx',
#  'Broome',
#  'Clinton',
#  'Erie',
#  'Jefferson',
#  'Fulton',
#  'Madison',
#  'Kings',
#  'Genesee',
#  'Lewis',
#  'Franklin',
#  'Montgomery',
#  'Orange',
#  'Yates',
#  'Cortland',
#  'Richmond',
#  'Cattaraugus',
#  'Herkimer',
#  'Niagara',
#  'Putnam']

# %%
df_places.plot(column = 'Hospital County')
# Out:
# <AxesSubplot:>

# %%
manha = df_places[df_places['Hospital County'] == 'St Lawrence']

# %%
manha[0:2]
# Out:
#            geoid Hospital County  \
# 16  05000US36089     St Lawrence
#
#                                              geometry
# 16  MULTIPOLYGON (((-75.26117 44.13612, -75.46673 ...

# %%
df_merged = pd.merge(df_categorical,df_places, on="Hospital County", how="left" )

# %%
df_merged.head()
# Out:
#   Hospital Service Area Hospital County                 Facility Name  \
# 0         Hudson Valley     Westchester  White Plains Hospital Center
# 1         Hudson Valley     Westchester  White Plains Hospital Center
# 2         Hudson Valley     Westchester  White Plains Hospital Center
# 3         Hudson Valley     Westchester  White Plains Hospital Center
# 4         Hudson Valley     Westchester  White Plains Hospital Center
#
#   Zip Code - 3 digits Gender    Age Group                    Race  \
# 0                 106      M     30 to 49              Other Race
# 1                 105      F  70 or Older  Black/African American
# 2                 105      F     50 to 69              Other Race
# 3                 106      F     50 to 69  Black/African American
# 4                 105      F  70 or Older              Other Race
#
#            Ethnicity                   Patient Disposition  \
# 0  Not Span/Hispanic                     Home or Self Care
# ...

# %%
df_merged = df_merged[["geoid", "Hospital County", "geometry", "Age Group"]]

# %%
CrosstabResult3 = pd.crosstab(index=df_merged['Hospital County'],columns=df_merged['Age Group'])
display(CrosstabResult3)
# Out:
# Age Group        0 to 17  18 to 29  30 to 49  50 to 69  70 or Older
# Hospital County
# Albany              9364      5639     12369     21435        20536
# Allegany             373       263       256       389          600
# Bronx              23682     18786     35982     58701        40731
# Broome              3037      2789      4720      8675        10281
# Cattaraugus          713       786      1034      1855         2159
# Cayuga               366       479       827      1233         1759
# Chautauqua          1330      1472      1994      2394         2842
# Chemung             1547      1629      2341      3653         3776
# Chenango             235       176       155       258          419
# Clinton              967       740      1206      2630         3370
# Columbia             213       484       822      1679         2391
# Cortland             325       453       586       982         1279
# Delaware               0        35        78       127          251
# ...

# %%
d = CrosstabResult3.reset_index().rename_axis(None, axis=1)

# %%
d.head()
# Out:
#   Hospital County  0 to 17  18 to 29  30 to 49  50 to 69  70 or Older
# 0          Albany     9364      5639     12369     21435        20536
# 1        Allegany      373       263       256       389          600
# 2           Bronx    23682     18786     35982     58701        40731
# 3          Broome     3037      2789      4720      8675        10281
# 4     Cattaraugus      713       786      1034      1855         2159

# %%
merged = pd.merge(d, df_places, on = 'Hospital County', how='left')

# %%
merged.head()
# Out:
#   Hospital County  0 to 17  18 to 29  30 to 49  50 to 69  70 or Older  \
# 0          Albany     9364      5639     12369     21435        20536
# 1        Allegany      373       263       256       389          600
# 2           Bronx    23682     18786     35982     58701        40731
# 3          Broome     3037      2789      4720      8675        10281
# 4     Cattaraugus      713       786      1034      1855         2159
#
#           geoid                                           geometry
# 0  05000US36001  MULTIPOLYGON (((-74.24102 42.55182, -74.23696 ...
# 1  05000US36003  MULTIPOLYGON (((-77.95488 42.51837, -77.84069 ...
# 2  05000US36005  MULTIPOLYGON (((-73.93365 40.88246, -73.92982 ...
# 3  05000US36007  MULTIPOLYGON (((-75.85039 42.32773, -75.84379 ...
# 4  05000US36009  MULTIPOLYGON (((-79.06071 42.34792, -79.06078 ...

# %%
from geopandas import GeoDataFrame

merged = GeoDataFrame(merged)

# %%
max_white = merged[merged['Multi-racial']==merged['Multi-racial'].max()]
max_white
# Out:
#    Hospital County  Black/African American  Multi-racial  Other Race   White  \
# 25       Manhattan                   66495         14604      133340  171443
#
#            geoid                                           geometry
# 25  05000US36061  MULTIPOLYGON (((-74.03444 40.68683, -74.02628 ...

# %%
fig1, gax = plt.subplots(figsize = (10,8))
merged.plot(column = 'Hospital County',ax = gax)
merged.plot(column = '0 to 17',edgecolor='black', ax = gax, legend=True, cmap='rainbow')
plt.axis('off')    
plt.show()

#vmin=0.0, vmax=1.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-1ae28965f7a4> in <module>
# ----> 1 fig1, gax = plt.subplots(figsize = (10,8))
#       2 merged.plot(column = 'Hospital County',ax = gax)
#       3 merged.plot(column = '70 or Older',edgecolor='black', ax = gax, legend=True, cmap='rainbow')
#       4 plt.axis('off')
#       5 plt.show()
#
# NameError: name 'plt' is not defined

# %%
from prince import MCA, FAMD

# %%
#'Operating Certificate Number', 'Permanent Facility Id',
#       'Discharge Year', 'APR DRG Code', 'APR MDC Code',
#       'APR Severity of Illness Code', 'Emergency Department Indicator'
#
# Facility Name                       0
#Age Group                           0
#Gender                              0
#Race                                0
#Ethnicity                           0
#Length of Stay                      0
#Type of Admission                   0
#Patient Disposition                 0
#Discharge Year                      0
#APR Medical Surgical Description    0
#Payment Typology 1                  0
#Emergency Department Indicator      0
#Total Charges                       0
#Total Costs                         0

# %%
df['Operating Certificate Number'].fillna(0,inplace=True)
df['Permanent Facility Id'].fillna(0,inplace=True)
df['APR DRG Code'].fillna(0,inplace=True)
df['APR MDC Code'].fillna(0,inplace=True)
df['APR Severity of Illness Code'].fillna(0,inplace=True)

# %%
df.drop('Birth Weight', axis=1, inplace=True)
df.drop('CCSR Procedure Code', axis=1, inplace=True)
df.drop('CCSR Procedure Description', axis=1, inplace=True)
df.drop('Payment Typology 2', axis=1, inplace=True)
df.drop('Payment Typology 3', axis=1, inplace=True)

# %%
df_no_na = df.dropna()

# %%
df_no_na.head()
# Out:
#   Hospital Service Area Hospital County  Operating Certificate Number  \
# 0         Hudson Valley     Westchester                     5902001.0
# 1         Hudson Valley     Westchester                     5902001.0
# 2         Hudson Valley     Westchester                     5902001.0
# 3         Hudson Valley     Westchester                     5902001.0
# 4         Hudson Valley     Westchester                     5902001.0
#
#    Permanent Facility Id                 Facility Name    Age Group  \
# 0                 1045.0  White Plains Hospital Center     30 to 49
# 1                 1045.0  White Plains Hospital Center  70 or Older
# 2                 1045.0  White Plains Hospital Center     50 to 69
# 3                 1045.0  White Plains Hospital Center     50 to 69
# 4                 1045.0  White Plains Hospital Center  70 or Older
#
#   Zip Code - 3 digits Gender                    Race          Ethnicity  \
# ...

# %%
df_no_na.dtypes
# Out:
# Hospital Service Area                   object
# Hospital County                         object
# Operating Certificate Number           float64
# Permanent Facility Id                  float64
# Facility Name                           object
# Age Group                               object
# Zip Code - 3 digits                     object
# Gender                                  object
# Race                                    object
# Ethnicity                               object
# Length of Stay                          object
# Type of Admission                       object
# Patient Disposition                     object
# Discharge Year                           int64
# CCSR Diagnosis Code                     object
# CCSR Diagnosis Description              object
# APR DRG Code                           float64
# APR DRG Description                     object
# APR MDC Code                           float64
# APR MDC Description                     object
# ...

# %%
print(cat)
# Out:
# ['Gender', 'Age Group', 'CCSR Diagnosis Description', 'Length of Stay', 'Payment Typology 2', 'Total Charges', 'APR Risk of Mortality', 'Hospital County', 'Ethnicity', 'Payment Typology 1', 'APR Medical Surgical Description', 'APR Severity of Illness Description', 'APR DRG Description', 'Total Costs', 'Zip Code - 3 digits', 'Birth Weight', 'Type of Admission', 'CCSR Procedure Description', 'APR MDC Description', 'Patient Disposition', 'Race', 'Facility Name', 'CCSR Procedure Code', 'Payment Typology 3', 'CCSR Diagnosis Code', 'Hospital Service Area']

# %%
# df = df.astype(int)

# %%
df_no_na['Operating Certificate Number'] = df_no_na['Operating Certificate Number'] .astype('int64')
# Out:
# <ipython-input-16-f79e6d246f15>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_na['Permanent Facility Id'] = df_no_na['Permanent Facility Id'] .astype('int64')
# Out:
# <ipython-input-17-1080d32b23e8>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_na['APR Severity of Illness Code'] = df_no_na['APR Severity of Illness Code'] .astype('int64')
# Out:
# <ipython-input-18-b878adfb6e41>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_na['APR DRG Code'] = df_no_na['APR DRG Code'] .astype('int64')
# Out:
# <ipython-input-19-9ecc2d2124ec>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_na['Emergency Department Indicator'] = df_no_na['Emergency Department Indicator'] .astype('object')
# Out:
# <ipython-input-20-b7f4267e9c5f>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_na['APR MDC Code'] = df_no_na['APR MDC Code'] .astype('int64')
# Out:
# <ipython-input-21-8acd244d61b0>:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_no_na.dtypes
# Out:
# Hospital Service Area                  object
# Hospital County                        object
# Operating Certificate Number            int64
# Permanent Facility Id                   int64
# Facility Name                          object
# Age Group                              object
# Zip Code - 3 digits                    object
# Gender                                 object
# Race                                   object
# Ethnicity                              object
# Length of Stay                         object
# Type of Admission                      object
# Patient Disposition                    object
# Discharge Year                          int64
# CCSR Diagnosis Code                    object
# CCSR Diagnosis Description             object
# APR DRG Code                            int64
# APR DRG Description                    object
# APR MDC Code                            int64
# APR MDC Description                    object
# ...

# %%
#df_no_na.drop('Facility Name', axis=1, inplace=True)

# %%
#df_no_na.drop('APR DRG Description', axis=1, inplace=True)

# %%
#df_no_na.drop('APR MDC Description', axis=1, inplace=True)

# %%
#df_no_na.drop('APR Medical Surgical Description', axis=1, inplace=True)

# %%
#df_no_na.drop('Operating Certificate Number', axis=1, inplace=True)

# %%
#df_no_na.drop('Payment Typology 1', axis=1, inplace=True)

# %%
df_no_na.isna().sum()
# Out:
# index                                  0
# Hospital Service Area                  0
# Hospital County                        0
# Permanent Facility Id                  0
# Facility Name                          0
# Age Group                              0
# Zip Code - 3 digits                    0
# Gender                                 0
# Race                                   0
# Ethnicity                              0
# Length of Stay                         0
# Type of Admission                      0
# Patient Disposition                    0
# Discharge Year                         0
# CCSR Diagnosis Code                    0
# CCSR Procedure Code                    0
# APR DRG Code                           0
# APR MDC Code                           0
# APR Severity of Illness Code           0
# APR Severity of Illness Description    0
# APR Risk of Mortality                  0
# Emergency Department Indicator         0
# Total Charges                          0
# ...

# %%
df_no_na = df_no_na.reset_index()

# %%
subset=df_no_na.sample(2000)

# %%
famd = FAMD(n_components =2, n_iter = 3, random_state = 101)
famd1 = FAMD(n_components =2, n_iter = 3, random_state = 101)
famd2 = FAMD(n_components =2, n_iter = 3, random_state = 101)

# %%
famd.fit(subset.drop('Race', axis = 1)) 
famd1.fit(subset.drop('Age Group', axis = 1)) 
famd2.fit(subset.drop('Hospital County', axis = 1))
# Out:
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# ...

# %%
df_famd= famd.transform(subset)
df_famd1= famd1.transform(subset)
df_famd2= famd2.transform(subset)
# Out:
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# ...

# %%
ax = famd.plot_row_coordinates(subset,color_labels=['Race {}'.format(t) for t in subset['Race']] )
ax = famd1.plot_row_coordinates(subset,color_labels=['Age {}'.format(t) for t in subset['Age Group']] )
#ax = famd2.plot_row_coordinates(subset,color_labels=['County {}'.format(t) for t in subset['Hospital County']] )
# Out:
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#
# c:\Users\natal\anaconda3\lib\site-packages\prince\mfa.py:98: FutureWarning:
#
# In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`

# %%
mca = MCA(n_components = 2, n_iter = 3, random_state = 101)

# %%
mca.fit(data_encoded)
# Out:
# MCA(n_iter=3, random_state=101)

# %%
data_encoded_mca = mca.transform(data_encoded)

# %%
data_encoded_mca.head()
# Out:
#           0         1
# 0 -0.085324 -0.189637
# 1  1.148301 -0.328702
# 2  0.091474 -0.227324
# 3  0.978879 -0.281028
# 4 -0.045706 -0.182463

# %%
try:
    mca.plot_coordinates(X = data_encoded)
except ZeroDivisionError:
    print("can't")
# Out:
# can't
# C:\Users\natal\AppData\Roaming\Python\Python39\site-packages\IPython\core\pylabtools.py:132: UserWarning:
#
# Creating legend with loc="best" can be slow with large amounts of data.

# %%
non = df.dropna()

# %%
newborn = non[non['CCSR Diagnosis Code'] == 'PNL001']

# %%
non['Type of Admission'].unique().tolist()
# Out:
# ['Newborn', 'Emergency', 'Elective', 'Urgent', 'Not Available']

# %%
newborn.head()
# Out:
#     Hospital Service Area Hospital County  Operating Certificate Number  \
# 396         New York City           Kings                     7001020.0
# 412         New York City       Manhattan                     7002024.0
# 434         New York City          Queens                     7003010.0
# 462         New York City          Queens                     7003010.0
# 481         New York City          Queens                     7003010.0
#
#      Permanent Facility Id                   Facility Name Age Group  \
# 396                 1305.0       Maimonides Medical Center   0 to 17
# 412                 1456.0            Mount Sinai Hospital   0 to 17
# 434                 1637.0  New York - Presbyterian/Queens   0 to 17
# 462                 1637.0  New York - Presbyterian/Queens   0 to 17
# 481                 1637.0  New York - Presbyterian/Queens   0 to 17
#
#     Zip Code - 3 digits Gender        Race          Ethnicity Length of Stay  \
# ...

# %%
nb_pivotTable = newborn.pivot_table(columns = ['Hospital County'], aggfunc='size')
nb_pivotTable
# Out:
# Hospital County
# Albany            7
# Allegany          1
# Bronx            15
# Broome          375
# Cattaraugus       1
# Chautauqua        1
# Chemung           1
# Clinton           2
# Erie             77
# Genesee           1
# Jefferson         4
# Kings          7515
# Madison         420
# Manhattan      9277
# Monroe            1
# Nassau         1066
# Niagara           1
# Orange            1
# Queens         3867
# Richmond       1981
# Schenectady      10
# St Lawrence     157
# Suffolk          41
# Tompkins        231
# Ulster            2
# Westchester     553
# dtype: int64

# %%
newborn[newborn['Hospital County'] == 'Allegany']
# Out:
#         Hospital Service Area Hospital County  Operating Certificate Number  \
# 1996299            Western NY        Allegany                      228000.0
#
#          Permanent Facility Id  \
# 1996299                   39.0
#
#                                              Facility Name Age Group  \
# 1996299  Memorial Hosp of Wm F & Gertrude F Jones A/K/A...   0 to 17
#
#         Zip Code - 3 digits Gender        Race          Ethnicity  \
# 1996299                 148      F  Other Race  Not Span/Hispanic
#
#         Length of Stay Type of Admission Patient Disposition  Discharge Year  \
# 1996299              2           Newborn   Home or Self Care            2019
#
#         CCSR Diagnosis Code CCSR Diagnosis Description CCSR Procedure Code  \
# 1996299              PNL001                   LIVEBORN              ADM010
#
#         CCSR Procedure Description  APR DRG Code  \
# 1996299               VACCINATIONS         640.0
#
# ...

# %%
newborn.shape
# Out:
# (25608, 33)
